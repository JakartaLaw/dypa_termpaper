# %%
from parameters import parameters as par
from model import Model
import pickle

# %%
V_star, C_star = Model().solve(par)
# Out:
# ======== BEGINNING ============
# Solution at time step t:  89 , time is:  2019-05-12 11:26:50.137852
# 0 time is:  2019-05-12 11:26:50.547687
# /Users/Jeppe/.local/share/virtualenvs/dypa_termpaper-laBhpRgB/lib/python3.7/site-packages/scipy/optimize/_minimize.py:761: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   "defaulting to absolute tolerance.", RuntimeWarning)
# ======== ENDING ===========
#  t = 89 solved in 1.2 secs
# ======== BEGINNING ============
# Solution at time step t:  88 , time is:  2019-05-12 11:26:51.364333
# 0 time is:  2019-05-12 11:26:51.364662
# /Users/Jeppe/.local/share/virtualenvs/dypa_termpaper-laBhpRgB/lib/python3.7/site-packages/scipy/optimize/_minimize.py:761: RuntimeWarning: Method 'bounded' does not support relative tolerance in x; defaulting to absolute tolerance.
#   "defaulting to absolute tolerance.", RuntimeWarning)
# ======== ENDING ===========
#  t = 88 solved in 12.4 secs
# ...

# %%
vs = pickle.dumps(V_star)
pickle.loads(vs)
# Out:
# {90: array([27.42062449, 27.42062449, 27.42062449, 27.42062449, 27.42062449,
#         27.42062449, 27.42062449, 27.42062449, 27.42062449, 27.42062449,
#         27.42062449, 27.42062449, 27.42062449, 27.42062449, 27.42062449,
#         27.42062449, 36.86671636, 36.86671636, 36.86671636, 36.86671636,
#         36.86671636, 36.86671636, 36.86671636, 36.86671636, 36.86671636,
#         36.86671636, 36.86671636, 36.86671636, 36.86671636, 36.86671636,
#         36.86671636, 36.86671636, 40.13645133, 40.13645133, 40.13645133,
#         40.13645133, 40.13645133, 40.13645133, 40.13645133, 40.13645133,
#         40.13645133, 40.13645133, 40.13645133, 40.13645133, 40.13645133,
#         40.13645133, 40.13645133, 40.13645133, 42.25701434, 42.25701434,
#         42.25701434, 42.25701434, 42.25701434, 42.25701434, 42.25701434,
#         42.25701434, 42.25701434, 42.25701434, 42.25701434, 42.25701434,
#         42.25701434, 42.25701434, 42.25701434, 42.25701434]),
# ...

# %%
cs = pickle.dumps(C_star)
pickle.loads(cs)
# Out:
# {90: array([[1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
#         [1.00793684e+01, 0.00000000e+00, 0.00000000e+00],
# ...
